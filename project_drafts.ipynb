# %% [markdown]
# <a href="https://colab.research.google.com/github/polock11/nlp_fall_2023/blob/main/project_drafts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('gutenberg')
#from nltk.corpus import brown
#from nltk.tag.tnt import FreqDist
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
emma = nltk.Text(nltk.corpus.gutenberg.words())
emma.concordance("wonderful")

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
e = 'this is an example showing stop word filteration'
stop_words = set(stopwords.words('english'))

l = [word for word in word_tokenize(e) if word not in stop_words]

l
# Out:
# ['example', 'showing', 'stop', 'word', 'filteration']

# %%
from nltk.stem import lancaster
from nltk.stem import PorterStemmer

ps = PorterStemmer()

exp = ["python","pythoning","pythonly","pythoned","pythoner"]

#stems = [ps.stem(w) for w in exp]

exm2 = f""" It is very important to
            be pythonly while you are pythoning with python
            All pythoners has some python knowledge."""
words = word_tokenize(exm2)

st = [ps.stem(word) for word in words]
#st

sno = nltk.stem.SnowballStemmer('english')
snow_stem = [sno.stem(word) for word in words]
#snow_stem


from nltk.stem.lancaster import LancasterStemmer
ls = LancasterStemmer()
lancaster_stem = [ls.stem(word) for word in words]

lancaster_stem
# Out:
# ['it',
#  'is',
#  'very',
#  'import',
#  'to',
#  'be',
#  'python',
#  'whil',
#  'you',
#  'ar',
#  'python',
#  'with',
#  'python',
#  'al',
#  'python',
#  'has',
#  'som',
#  'python',
#  'knowledg',
#  '.']

# %% [markdown]
# <h1>POS tagging</h1>

# %%
from nltk.tokenize import PunktSentenceTokenizer

from nltk.corpus import gutenberg

hamlet_text = gutenberg.raw('shakespeare-hamlet.txt')
print(hamlet_text[:1000])
# Out:
# [The Tragedie of Hamlet by William Shakespeare 1599]
#
#
# Actus Primus. Scoena Prima.
#
# Enter Barnardo and Francisco two Centinels.
#
#   Barnardo. Who's there?
#   Fran. Nay answer me: Stand & vnfold
# your selfe
#
#    Bar. Long liue the King
#
#    Fran. Barnardo?
#   Bar. He
#
#    Fran. You come most carefully vpon your houre
#
#    Bar. 'Tis now strook twelue, get thee to bed Francisco
#
#    Fran. For this releefe much thankes: 'Tis bitter cold,
# And I am sicke at heart
#
#    Barn. Haue you had quiet Guard?
#   Fran. Not a Mouse stirring
#
#    Barn. Well, goodnight. If you do meet Horatio and
# Marcellus, the Riuals of my Watch, bid them make hast.
# Enter Horatio and Marcellus.
#
#   Fran. I thinke I heare them. Stand: who's there?
#   Hor. Friends to this ground
#
#    Mar. And Leige-men to the Dane
#
#    Fran. Giue you good night
#
#    Mar. O farwel honest Soldier, who hath relieu'd you?
#   Fra. Barnardo ha's my place: giue you goodnight.
#
# Exit Fran.
#
# ...

# %%
nltk.download('brown')
from nltk.corpus import brown
from nltk.tokenize import sent_tokenize
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
raw_txt = brown.raw('cn10')

words = brown.words()

tagged = nltk.pos_tag(words[:10]);
tagged
# Out:
# [('The', 'DT'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('Grand', 'NNP'),
#  ('Jury', 'NNP'),
#  ('said', 'VBD'),
#  ('Friday', 'NNP'),
#  ('an', 'DT'),
#  ('investigation', 'NN'),
#  ('of', 'IN')]

# %% [markdown]
# <h1>Chunking</h1>

# %%
import spacy as sp
dictonary = sp.load('en_core_web_sm')
text = f"""
            The iPhone 14 and iPhone 14 Plus
            are smartphones designed, developed,
            and marketed by Apple Inc. They are the
            sixteenth-generation iPhones, succeeding the
            iPhone 13 and iPhone 13 Mini, and were announced
            during Apple Event, Apple Park in Cupertino, California,
            on September 7, 2022, alongside the higher-priced iPhone
            14 Pro and iPhone 14 Pro Max flagships. The iPhone 14 and
            iPhone 14 Plus feature a 6.1-inch (15 cm) and 6.7-inch (17 cm)
            display, improvements to the rear-facing camera, and satellite
            connectivity for contacting emergency services when a user in
            trouble is beyond the range of Wi-Fi or cellular networks.[11][12]
            The iPhone 14 was made available on September 16, 2022,[13] and
            iPhone 14 Plus was made available on October 7, 2022, priced at
            $799 and $899 respectively and was launched with iOS 16.[8][14]
            Pre-orders for the iPhone 14 and iPhone 14 Plus began on
            September 9, 2022.[15] Along with the 14 Pro and 14 Pro Max,
            the iPhone 14 and 14 Plus are the last iPhones to feature the
            Lightning port, as their successors, the iPhone 15 and 15 Plus
            (announced on September 12, 2023), use a USB-C port instead,
            per European Commission regulation.[16][17]

            The iPhone 14 does not have a "Mini" version like its
            predecessor, the iPhone 13 Mini. Instead, Apple has
            reintroduced a larger dimension iPhone 14 named the iPhone
            14 Plus. Apple has not introduced a Plus model iPhone since
            the iPhone 8 Plus in 2017. iPhone 14 and 14 Plus models (as
            well as iPhone 14 Pro and iPhone 14 Pro Max models) sold in
            the United States drop support for physical SIM cards, making
            them the first iPhone models since the CDMA variant of the
            iPhone 4 to not come with a discrete SIM card reader.[18]
        """
doc = dictonary(str(text))

# for ent in doc.ents:
#     print(ent.text + "-----" + ent.label_)

sp.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>            The iPhone 14 and iPhone 14 Plus are smartphones designed, developed, and marketed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  They are the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sixteenth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -generation
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhones
# ...

# %%
sp.explain("NORP")
# Out:
# 'Nationalities or religious or political groups'

# %%
pip install flair

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
from segtok.segmenter import split_single
tagger = SequenceTagger.load('ner-ontonotes')

text = f"""
            The iPhone 14 and iPhone 14 Plus
            are smartphones designed, developed,
            and marketed by Apple Inc. They are the
            sixteenth-generation iPhones, succeeding the
            iPhone 13 and iPhone 13 Mini, and were announced
            during Apple Event, Apple Park in Cupertino, California,
            on September 7, 2022, alongside the higher-priced iPhone
            14 Pro and iPhone 14 Pro Max flagships. The iPhone 14 and
            iPhone 14 Plus feature a 6.1-inch (15 cm) and 6.7-inch (17 cm)
            display, improvements to the rear-facing camera, and satellite
            connectivity for contacting emergency services when a user in
            trouble is beyond the range of Wi-Fi or cellular networks.[11][12]
            The iPhone 14 was made available on September 16, 2022,[13] and
            iPhone 14 Plus was made available on October 7, 2022, priced at
            $799 and $899 respectively and was launched with iOS 16.[8][14]
            Pre-orders for the iPhone 14 and iPhone 14 Plus began on
            September 9, 2022.[15] Along with the 14 Pro and 14 Pro Max,
            the iPhone 14 and 14 Plus are the last iPhones to feature the
            Lightning port, as their successors, the iPhone 15 and 15 Plus
            (announced on September 12, 2023), use a USB-C port instead,
            per European Commission regulation.[16][17]

            The iPhone 14 does not have a "Mini" version like its
            predecessor, the iPhone 13 Mini. Instead, Apple has
            reintroduced a larger dimension iPhone 14 named the iPhone
            14 Plus. Apple has not introduced a Plus model iPhone since
            the iPhone 8 Plus in 2017. iPhone 14 and 14 Plus models (as
            well as iPhone 14 Pro and iPhone 14 Pro Max models) sold in
            the United States drop support for physical SIM cards, making
            them the first iPhone models since the CDMA variant of the
            iPhone 4 to not come with a discrete SIM card reader.[18]
        """

sentence = [Sentence(sent, use_tokenizer = True) for sent in split_single(text)]
tagger.predict(sentence)

for sent in sentence:
    for entity in sent.get_spans('ner'):
        print(entity)
# Out:
# ...
# 2023-09-23 12:37:49,747 SequenceTagger predicts: Dictionary with 75 tags: O, S-PERSON, B-PERSON, E-PERSON, I-PERSON, S-GPE, B-GPE, E-GPE, I-GPE, S-ORG, B-ORG, E-ORG, I-ORG, S-DATE, B-DATE, E-DATE, I-DATE, S-CARDINAL, B-CARDINAL, E-CARDINAL, I-CARDINAL, S-NORP, B-NORP, E-NORP, I-NORP, S-MONEY, B-MONEY, E-MONEY, I-MONEY, S-PERCENT, B-PERCENT, E-PERCENT, I-PERCENT, S-ORDINAL, B-ORDINAL, E-ORDINAL, I-ORDINAL, S-LOC, B-LOC, E-LOC, I-LOC, S-TIME, B-TIME, E-TIME, I-TIME, S-WORK_OF_ART, B-WORK_OF_ART, E-WORK_OF_ART, I-WORK_OF_ART, S-FAC
# 2023-09-23 12:37:50,356 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-09-23 12:37:50,365 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# Span[1:2]: "iPhone" → PRODUCT (0.7713)
# Span[2:3]: "14" → CARDINAL (0.4696)
# Span[4:6]: "iPhone 14" → PRODUCT (0.7086)
# Span[3:5]: "Apple Inc" → ORG (0.9623)
# Span[1:2]: "iPhones" → PRODUCT (0.8523)
# Span[0:2]: "iPhone 13" → PRODUCT (0.7053)
# ...

# %%
import nltk
print(nltk.__file__)
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/__init__.py

# %% [markdown]
# <h1>WordNet</h1>

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet

syns = wordnet.synsets('program')

#synset
#print(syns[0].name())

#just the word
#print(syns[0].lemmas()[0].name())

#definition
#print(syns[0].definition())

#examples
#print(syns[0].examples())

s = [l.name() for syn in wordnet.synsets("good") for l in syn.lemmas()];
a = [l.antonyms()[0].name() for syn in wordnet.synsets('good') for l in syn.lemmas() if l.antonyms()];


# for syn in wordnet.synsets('good'):
#     for l in syn.lemmas():
#         s.append(l.name())
#         if l.antonyms():
#             a.append(l.antonyms()[0].name())

s
# Out:
# ['good',
#  'good',
#  'goodness',
#  'good',
#  'goodness',
#  'commodity',
#  'trade_good',
#  'good',
#  'good',
#  'full',
#  'good',
#  'good',
#  'estimable',
#  'good',
#  'honorable',
#  'respectable',
#  'beneficial',
#  'good',
#  'good',
#  'good',
#  'just',
#  'upright',
#  'adept',
#  'expert',
#  'good',
#  'practiced',
#  'proficient',
#  'skillful',
#  'skilful',
#  'good',
#  'dear',
#  'good',
#  'near',
#  'dependable',
#  'good',
#  'safe',
#  'secure',
#  'good',
#  'right',
#  'ripe',
#  'good',
#  'well',
#  'effective',
#  'good',
#  'in_effect',
#  'in_force',
#  'good',
#  'good',
#  'serious',
#  'good',
#  'sound',
#  'good',
#  'salutary',
#  'good',
#  'honest',
#  'good',
#  'undecomposed',
#  'unspoiled',
#  'unspoilt',
#  'good',
#  'well',
#  'good',
#  'thoroughly',
#  'soundly',
#  'good']

# %%
# SEMENTIC similarity

w1 = wordnet.synset("building.n.01")
w2 = wordnet.synset("bridge.n.01")
print(w1.wup_similarity(w2))
# Out:
# 0.8571428571428571

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
from unicodedata import category
import nltk
import random
from nltk.corpus import movie_reviews

documents = [(list(movie_reviews.words(fileid)),category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]
random.shuffle(documents)
documents[1]

# %%
documents[0]

# %%
import numpy as np
from numpy.linalg import norm

a = [0,0,0,0,0,.176,0,0,.477,0,.176]
b = [0,0,.477,0,.477,.176,0,0,0,.176,0]

sim = np.dot(a,b)/(norm(a) * norm(b))
sim
# Out:
# 0.08006926315282352

# %% [markdown]
# <h1>LESK Algorithm</h1>

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk

# Sample sentence
sentence = "Kick the ball slowly"

# Target word to disambiguate
target_word = "Kick"

# Perform Word Sense Disambiguation using LESK
sense = lesk(sentence.split(), target_word)

# Print the most likely sense and its definition
if sense:
    print("Target Word:", target_word)
    print("Most Likely Sense:", sense.name())
    print("Sense Definition:", sense.definition())
else:
    print("No sense found (ambiguous or not in WordNet).")
# Out:
# Target Word: Kick
# Most Likely Sense: recoil.n.01
# Sense Definition: the backward jerk of a gun when it is fired

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import wordnet as wn

# %%
import nltk
nltk.download('punkt')

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

cotext_sentence = "i need the car"
amb_word = "car"

max_overlap = 0
lesk_sense = None
lesk_definition = ''
context_words = nltk.word_tokenize(cotext_sentence)
context_words = set(context_words)

for sense in wn.synsets(amb_word):
    print(f"sense: {sense}")
    signature = set()
    sense_definitions = nltk.word_tokenize(sense.definition())
    print(f'sense_definitions : {sense_definitions}')
    signature = signature.union(set(sense_definitions))
    signature = signature.union(set(sense.lemma_names()))
    print(f"examples: {sense.examples()}")
    for example in sense.examples():
        signature = signature.union(set(example.split()))

    print(f"final signature: {signature}")
    overlap  = len(context_words.intersection(signature))
    if overlap > max_overlap:
        lesk_sense = sense
        max_overlap = overlap
        lesk_definition = sense.definition()

print(lesk_sense)
print(lesk_definition)
# Out:
# sense: Synset('car.n.01')
# sense_definitions : ['a', 'motor', 'vehicle', 'with', 'four', 'wheels', ';', 'usually', 'propelled', 'by', 'an', 'internal', 'combustion', 'engine']
# examples: ['he needs a car to get to work']
# final signature: {'he', 'to', 'engine', 'usually', 'auto', 'with', 'four', 'vehicle', 'combustion', 'by', 'car', 'a', 'needs', 'machine', 'an', 'motor', 'motorcar', 'get', ';', 'automobile', 'propelled', 'wheels', 'work', 'internal'}
# sense: Synset('car.n.02')
# sense_definitions : ['a', 'wheeled', 'vehicle', 'adapted', 'to', 'the', 'rails', 'of', 'railroad']
# examples: ['three cars had jumped the rails']
# final signature: {'railroad_car', 'to', 'rails', 'three', 'railroad', 'had', 'adapted', 'jumped', 'vehicle', 'cars', 'car', 'a', 'of', 'railcar', 'wheeled', 'the', 'railway_car'}
# sense: Synset('car.n.03')
# ...

# %%
sig = {'he', 'excellent', 'gave', 'foot', 'powerful', 'boot', 'kick', 'with', "team's", 'a', 'act', 'blow', 'of', 'kicking', 'delivering', 'ball', 'the', 'was'}

for term in sig:
    synsets = wn.synsets(term)
    print(synsets)
    #synset_types = synsets.hyponyms()
    # print(synset_types)
# Out:
# [Synset('helium.n.01'), Synset('he.n.02')]
# [Synset('excellent.s.01')]
# ...

# %%
import nltk
import random
from nltk.corpus import senseval
nltk.download('senseval')
def senses(word):
    """
    This takes a target word from senseval-2 (find out what the possible
    are by running senseval.fileides()), and it returns the list of possible
    senses for the word
    """
    return list(set(i.senses[0] for i in senseval.instances(word)))
# Out:
# [nltk_data] Downloading package senseval to /root/nltk_data...
# [nltk_data]   Unzipping corpora/senseval.zip.

# %%
STOPWORDS = ['.', ',', '?', '"', '``', "''", "'", '--', '-', ':', ';', '(',
             ')', '$', '000', '1', '2', '10,' 'I', 'i', 'a', 'about', 'after', 'all', 'also', 'an', 'any',
             'are', 'as', 'at', 'and', 'be', 'being', 'because', 'been', 'but', 'by',
             'can', "'d", 'did', 'do', "don'", 'don', 'for', 'from', 'had', 'has', 'have', 'he',
             'her', 'him', 'his', 'how', 'if', 'is', 'in', 'it', 'its', "'ll", "'m", 'me',
             'more', 'my', 'n', 'no', 'not', 'of', 'on', 'one', 'or', "'re", "'s", "s",
             'said', 'say', 'says', 'she', 'so', 'some', 'such', "'t", 'than', 'that', 'the',
             'them', 'they', 'their', 'there', 'this', 'to', 'up', 'us', "'ve", 'was', 'we', 'were',
             'what', 'when', 'where', 'which', 'who', 'will', 'with', 'years', 'you',
             'your']

STOPWORDS_SET = set(STOPWORDS)



def wsd_context_features(instance, vocab, dist=3):
    features = {}
    ind = instance.position
    con = instance.context
    for i in range(max(0, ind - dist), ind):
        j = ind - i
        features['left-context-word-%s(%s)' % (j, con[i][0])] = True

    for i in range(ind + 1, min(ind + dist + 1, len(con))):
        j = i - ind
        features['right-context-word-%s(%s)' % (j, con[i][0])] = True

    features['word'] = instance.word
    features['pos'] = con[1][1]
    return features



def extract_vocab_frequency(instances, stopwords=STOPWORDS_SET, n=300):
    """
    Given a list of senseval instances, return a list of the n most frequent words that
    appears in its context (i.e., the sentence with the target word in), output is in order
    of frequency and includes also the number of instances in which that key appears in the
    context of instances.
    """
    fd = nltk.FreqDist()
    for i in instances:
        (target, suffix) = i.word.split('-')
        words = (c[0] for c in i.context if not c[0] == target)
        for word in set(words) - set(stopwords):
            fd[word] += 1
            # for sense in i.senses:
            # cfd[sense][word] += 1
    return fd.most_common()[:n + 1]


def extract_vocab(instances, stopwords=STOPWORDS_SET, n=300):
    return [w for w, f in extract_vocab_frequency(instances, stopwords, n)]

senseval.instances()[0]
# Out:
# SensevalInstance(word='hard-a', position=20, context=[('``', '``'), ('he', 'PRP'), ('may', 'MD'), ('lose', 'VB'), ('all', 'DT'), ('popular', 'JJ'), ('support', 'NN'), (',', ','), ('but', 'CC'), ('someone', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('kill', 'VB'), ('him', 'PRP'), ('to', 'TO'), ('defeat', 'VB'), ('him', 'PRP'), ('and', 'CC'), ('that', 'DT'), ("'s", 'VBZ'), ('hard', 'JJ'), ('to', 'TO'), ('do', 'VB'), ('.', '.'), ("''", "''")], senses=('HARD1',))

# %%
vocab = extract_vocab(senseval.instances(), stopwords=STOPWORDS_SET, n=300)

# %%
from nltk.corpus import senseval

# Get the first senseval instance
senseval_instance = senseval.instances()[0]

# Iterate through the context and extract word and pos
for context in senseval_instance.context:
    word, pos = context
    print(word)

# %%
context_sentence = "This is my home, this is where I live"
amb_word = "home"
max_overlap = 0
lesk_sense = None
lesk_definition = ''
context_words = nltk.word_tokenize(context_sentence)
context_words = set(context_words)

for sense in wn.synsets(amb_word):
    signature = set()
    sense_definitions = nltk.word_tokenize(sense.definition())
    signature = signature.union(set(sense_definitions))
    signature = signature.union(set(sense.lemma_names()))
    for example in sense.examples():
        signature = signature.union(set(example.split()))
    # Add hyponyms
    for hyponym in sense.hyponyms():
        print(f'hyponym: {hyponym}')
        hyponym_definitions = nltk.word_tokenize(hyponym.definition())
        print(f'hyponym_definitions: {hyponym_definitions}')
        signature = signature.union(set(hyponym_definitions))
        signature = signature.union(set(hyponym.lemma_names()))
        print(f'signature: {signature}')

    # Add hypernyms
    for hypernym in sense.hypernyms():
        hypernym_definitions = nltk.word_tokenize(hypernym.definition())
        signature = signature.union(set(hypernym_definitions))
        signature = signature.union(set(hypernym.lemma_names()))

    # Add synonyms
    for lemma in sense.lemmas():
        synonym_names = lemma.name().split("_")
        signature = signature.union(set(synonym_names))

    print(f"final_sig: {signature}")

    overlap = len(context_words.intersection(signature))
    if overlap > max_overlap:
        lesk_sense = sense
        max_overlap = overlap
        lesk_definition = sense.definition()


print(lesk_sense)
print(lesk_definition)

# %%
import nltk
from nltk.corpus import wordnet as wn

s = ['blow', 'delivering', 'gave', 'powerful', 'excellent']

hypernyms_list = []
hyponyms_list = []
synonyms_list = []

for word in s:
    synsets = wn.synsets(word)

    for synset in synsets:
        # Find hypernyms
        hypernyms_list.extend(synset.hypernyms())

        # Find hyponyms
        hyponyms_list.extend(synset.hyponyms())

        # Find synonyms
        for lemma in synset.lemmas():
            synonyms_list.append(lemma.name())

# Remove duplicates by converting the lists to sets and back to lists
hypernyms_list = list(set(hypernyms_list))
hyponyms_list = list(set(hyponyms_list))
synonyms_list = list(set(synonyms_list))

# Print the results
print("Hypernyms:", hypernyms_list)
print("Hyponyms:", hyponyms_list)
print("Synonyms:", synonyms_list)
# Out:
# Hypernyms: [Synset('permit.v.01'), Synset('release.v.08'), Synset('happening.n.01'), Synset('transfer.v.05'), Synset('administer.v.04'), Synset('wind.n.01'), Synset('fail.v.04'), Synset('save.v.03'), Synset('utter.v.02'), Synset('compensate.v.02'), Synset('inflict.v.01'), Synset('direct.v.04'), Synset('move.v.03'), Synset('communicate.v.01'), Synset('bring.v.04'), Synset('estimate.v.01'), Synset('fail.v.02'), Synset('send.v.01'), Synset('expel.v.01'), Synset('produce.v.01'), Synset('exhale.v.01'), Synset('toast.v.02'), Synset('pledge.v.04'), Synset('stretch.v.04'), Synset('state.v.01'), Synset('rest.v.03'), Synset('unwrap.v.02'), Synset('execute.v.04'), Synset('submit.v.01'), Synset('exhaust.v.05'), Synset('move.v.02'), Synset('express.v.01'), Synset('show.v.04'), Synset('give.v.01'), Synset('use.v.01'), Synset('offer.v.02'), Synset('give.v.03'), Synset('distribute.v.01'), Synset('stroke.n.12'), Synset('burst.v.01'), Synset('lead.v.05'), Synset('travel.v.01'), Synset('think.v.03'), S
# ...

# %%
import nltk
from nltk.wsd import lesk

# Download the wordnet data if you haven't already
nltk.download('wordnet')

# Sample sentence with the word 'bank'
context = "My name is April"

# Tokenize the context
context_tokens = nltk.word_tokenize(context)

# Perform word sense disambiguation using Lesk
sense = lesk(context_tokens, 'April')

# Print the sense and its definition
print("Word:", 'bank')
print("Sense:", sense)
print("Definition:", sense.definition())
# Out:
# Word: bank
# Sense: Synset('april.n.01')
# Definition: the month following March and preceding May
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
from nltk.corpus import wordnet

# Define the set of terms
sig = {'car'}

# Create sets to store the hyponyms and hypernyms
hyponyms_set = set()
hypernyms_set = set()

# Iterate through each term in 'sig'
for term in sig:
    # Get the synsets for the term (WordNet senses)
    synsets = wordnet.synsets(term)

    # For each synset, find its hyponyms and hypernyms
    for synset in synsets:
        hyponyms_set.update(synset.hyponyms())
        hypernyms_set.update(synset.hypernyms())

# Combine the hyponyms and hypernyms into a single set
hyponyms_and_hypernyms_set = hyponyms_set.union(hypernyms_set)

# Create a set to store the lemma names
lemma_names_set = set()

# Iterate through the hyponyms_and_hypernyms_set and get the lemma names
for synset in hyponyms_and_hypernyms_set:
    for lemma in synset.lemmas():
        l = lemma.name().lower().replace('_',' ').replace('-', ' ')

        #print(l)
        lemma_names_set.add(l)

# Print the resulting set of lemma names
print(lemma_names_set)
# Out:
# {'squad car', 'heap', 'freight car', 'electric automobile', 'automotive vehicle', 'secondhand car', 'subcompact', 'compact', 'stock car', 'electric', 'sports car', 'used car', 'van', 'sedan', 'cab', 'slip coach', 'patrol car', 'club car', 'station wagon', 'waggon', 'police car', 'carriage', 'prowl car', 'luggage van', 'stanley steamer', 'hatchback', 'minicar', 'racer', 'cabin car', 'limo', 'landrover', 'beach waggon', 'phaeton', 'hardtop', 'electric car', 'police cruiser', 'racing car', 'ambulance', 'horseless carriage', 'saloon', 'motor vehicle', "guard's van", 'roadster', 'slip carriage', 'touring car', 'subcompact car', 'suv', 'model t', 'coupe', 's.u.v.', 'taxi', 'wagon', 'sport car', 'estate car', 'tourer', 'sport utility vehicle', 'bus', 'mail car', 'convertible', 'station waggon', 'taxicab', 'hot rod', 'jeep', 'compact car', 'gas guzzler', 'wheeled vehicle', 'baggage car', 'loaner', 'cruiser', 'beach wagon', 'passenger car', 'hack', 'pace car', 'lounge car', 'race car', 'two s
# ...

# %%
import nltk
from nltk.corpus import wordnet

# Define the set of terms
sig = {'car'}

# def extend_sig(sig):
#     # Create a set to store the lemma names
#     lemma_names_set = set()

#     # Iterate through each term in 'sig'
#     for term in sig:
#         lemma_names_set = lemma_names_set.add(term)
#         # Get the synsets for the term (WordNet senses)
#         synsets = wordnet.synsets(term)

#         # For each synset, find its hyponyms and hypernyms
#         for synset in synsets:
#             hyponyms_set = set()
#             hypernyms_set = set()

#             hyponyms_set.update(synset.hyponyms())
#             #hypernyms_set.update(synset.hypernyms())

#             # Combine the hyponyms and hypernyms into a single set
#             hyponyms_and_hypernyms_set = hyponyms_set.union(hypernyms_set)

#             # Iterate through the hyponyms_and_hypernyms_set and get the lemma names
#             for synset in hyponyms_and_hypernyms_set:
#                 for lemma in synset.lemmas():
#                     l = lemma.name().lower().replace('_', ' ').replace('-', ' ')
#                     #print(l)
#                     lemma_names_set.add(l)

#     # Print the resulting set of lemma names
#     return lemma_names_set


from nltk.corpus import wordnet

# def extend_sig(sig):
#     # Create a set to store the lemma names
#     lemma_names_set = set()

#     # Iterate through each term in 'sig'
#     for term in sig:
#         lemma_names_set.add(term)  # Use add() to add elements to a set, not assignment

#         # Get the synsets for the term (WordNet senses)
#         synsets = wordnet.synsets(term)

#         # For each synset, find its hyponyms and hypernyms
#         for synset in synsets:
#             hyponyms_set = set()
#             hypernyms_set = set()

#             hyponyms_set.update(synset.hyponyms())
#             hypernyms_set.update(synset.hypernyms())  # Uncomment this line to include hypernyms

#             # Combine the hyponyms and hypernyms into a single set
#             hyponyms_and_hypernyms_set = hyponyms_set.union(hypernyms_set)

#             # Iterate through the hyponyms_and_hypernyms_set and get the lemma names
#             for synset in hyponyms_and_hypernyms_set:
#                 for lemma in synset.lemmas():
#                     l = lemma.name().lower().replace('_', ' ').replace('-', ' ')

#                     l = l.split()

#                     lemma_names_set.add(l)

#     # Print the resulting set of lemma names
#     return lemma_names_set

from nltk.corpus import stopwords

def extend_sig(sig):
    # Create a set to store the lemma names
    lemma_names_set = set()
    stop_words = set(stopwords.words("english"))
    sig = sig - stop_words


    # Iterate through each term in 'sig'
    for term in sig:
        lemma_names_set.add(term)

        # Get the synsets for the term (WordNet senses)
        synsets = wordnet.synsets(term)

        # For each synset, find its hyponyms and hypernyms
        for synset in synsets:
            hyponyms_set = set()
            hypernyms_set = set()

            hyponyms_set.update(synset.hyponyms())
            hypernyms_set.update(synset.hypernyms())

            # Combine the hyponyms and hypernyms into a single set
            hyponyms_and_hypernyms_set = hyponyms_set.union(hypernyms_set)

            # Iterate through the hyponyms_and_hypernyms_set and get the lemma names
            for synset in hyponyms_and_hypernyms_set:
                for lemma in synset.lemmas():
                    l = lemma.name().lower().replace('_', ' ').replace('-', ' ')

                    # Split the lemma name into individual words
                    words = l.split()

                    # Add each word to the lemma_names_set
                    lemma_names_set.update(words)

    # Print the resulting set of lemma names
    return lemma_names_set

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet
from nltk.corpus import stopwords


##########################################
def extend_sig(sig):
    lemma_names_set = set()
    stop_words = set(stopwords.words("english"))
    sig = sig - stop_words


    for term in sig:
        lemma_names_set.add(term)

        synsets = wordnet.synsets(term)

        # for each synset, find its hyponyms and hypernyms
        for synset in synsets:
            hyponyms_set = set()
            hypernyms_set = set()

            hyponyms_set.update(synset.hyponyms())
            hypernyms_set.update(synset.hypernyms())

            hyponyms_and_hypernyms_set = hyponyms_set.union(hypernyms_set)

            for synset in hyponyms_and_hypernyms_set:
                for lemma in synset.lemmas():
                    l = lemma.name().lower().replace('_', ' ').replace('-', ' ')

                    words = l.split()

                    lemma_names_set.update(words)

    # return extended signature
    return lemma_names_set

##########################################

"The exam was too hard for the studensts to pass"
'I am going to the bank with some money'

cotext_sentence = "The exam was too hard for the studensts to pass"
amb_word = "hard"

max_overlap = 0
lesk_sense = None
lesk_definition = ''
context_words = nltk.word_tokenize(cotext_sentence)
context_words = set(context_words)

for sense in wn.synsets(amb_word):
    print(f"sense: {sense}")
    signature = set()
    print(f"sense_definition: {sense.definition()}")
    sense_definitions = nltk.word_tokenize(sense.definition())
    signature = signature.union(set(sense_definitions))
    signature = signature.union(set(sense.lemma_names()))
    print(f"sense_examples: {sense.examples()}")
    for example in sense.examples():
        signature = signature.union(set(example.split()))
    print(f"base_signature_set: {signature}")
    signature = extend_sig(signature)
    print(f"extended_signature_set: {signature}")
    overlap  = len(context_words.intersection(signature))
    if overlap > max_overlap:
        lesk_sense = sense
        max_overlap = overlap
        lesk_definition = sense.definition()

print(f'sense in the senstence:{lesk_sense}')
print(f"definition: {lesk_definition}")

# %%
# Original set of terms
s = {'horseless carriage', 'stock car'}

# Create a new set to store the individual words
new_s = set()

# Iterate through each term in the original set
for term in s:
    # Split the term into individual words based on spaces
    words = term.split()
    print(words)

    # Add each word to the new set
    new_s.update(words)

# Print the new set with individual words
print(new_s)

# %%
import pandas as pd

# %%
df = pd.read_csv('data.txt', sep='\t', header=None)
df
# Out:
#                                                     0
# 0        1 Thu Aug 19 21:54:38 2021 125094     485...
# 1        2 Sat Jul 31 04:09:44 2021 174434     415...
# 2        3 Sat Aug 14 17:19:04 2021 8538286    407...
# 3        4 Mon Aug  2 18:23:45 2021 5521221    409...
# 4        5 Thu Jul 29 22:44:20 2021 3267767    413...
# 5        6 Sat Aug 14 03:57:47 2021 8411850    468...
# 6        7 Thu Aug 12 03:41:22 2021 6064250    470...
# 7        8 Sun Aug 22 10:29:58 2021 6871937    459...
# 8        9 Fri Aug  6 14:23:08 2021 2055930    410...
# 9       10 Sun Aug 15 13:43:51 2021 8775910    414...
# 10      11 Wed Aug  4 15:52:13 2021 4525747    446...
# 11      12 Wed Aug 18 02:22:15 2021 5276143    435...
# 12      13 Thu Aug 19 16:01:02 2021 5405144    457...
# 13      14 Tue Aug  3 14:55:00 2021 9309466    490...
# 14      15 Thu Aug  5 04:00:30 2021 6494070    401...
# 15      16 Sun Aug  8 13:08:17 2021 4880588    445...
# ...

# %%
df
# Out:
#     Rowid                 Timestamp  Anonymized Vehicle number Vehicle type  \
# 0       1  Thu Aug 19 21:54:38 2021                     125094          car
# 1       2  Sat Jul 31 04:09:44 2021                     174434          car
# 2       3  Sat Aug 14 17:19:04 2021                    8538286          car
# 3       4  Mon Aug  2 18:23:45 2021                    5521221          car
# 4       5  Thu Jul 29 22:44:20 2021                    3267767          car
# 5       6  Sat Aug 14 03:57:47 2021                    8411850          car
# 6       7  Thu Aug 12 03:41:22 2021                    6064250          car
# 7       8  Sun Aug 22 10:29:58 2021                    6871937          van
# 8       9  Fri Aug  6 14:23:08 2021                    2055930          car
# 9      10  Sun Aug 15 13:43:51 2021                    8775910          car
# 10     11  Wed Aug  4 15:52:13 2021                    4525747          car
# ...

# %%
with open('data.txt', 'r') as file:
    lines = file.readlines()

pc=[]
vc=[]

for line in lines:
    data = line.split(' ')
    pc.append(data[-2])
    vc.append(data[-1].strip('\n'))

# %%
df = pd.DataFrame({'Type of Payment code': pc,
                  'Vehicle Code':vc})
df.to_csv('txt_data.csv', index=False)

# %%
csv_data = pd.read_csv('csv_data.csv')
tsv_data = pd.read_csv('tsv_data.csv')
fixed_width_data = pd.read_csv('fixed_width_data.csv')

combined_df = pd.concat([csv_data, tsv_data, fixed_width_data], axis=1)


combined_df

df = combined_df[['Rowid'], ['Timestamp'],
                ['Anonymized Vehicle number'],['Vehicle type'],
                ['Number of axles'],['Tollplaza id'],
                ['Tollplaza code'],['Type of Payment code'],
                ['Vehicle Code']]
# Out:
#       Rowid                 Timestamp  Anonymized Vehicle number Vehicle type  \
# 0         1  Thu Aug 19 21:54:38 2021                     125094          car
# 1         2  Sat Jul 31 04:09:44 2021                     174434          car
# 2         3  Sat Aug 14 17:19:04 2021                    8538286          car
# 3         4  Mon Aug  2 18:23:45 2021                    5521221          car
# 4         5  Thu Jul 29 22:44:20 2021                    3267767          car
# ...     ...                       ...                        ...          ...
# 9995   9996  Sun Aug 15 03:02:27 2021                    3369206          car
# 9996   9997  Sat Aug  7 04:24:08 2021                    5886709        truck
# 9997   9998  Mon Aug  9 02:58:26 2021                     917421        truck
# 9998   9999  Tue Aug 17 18:41:00 2021                    2601682        truck
# 9999  10000  Mon Aug  9 22:56:50 2021                    4833266          car
#
# ...
